# %% [markdown]
# ## Demo for learning single channel PSF from bead data

# %% [markdown]
# ##### Setup environment

# %%
import sys
sys.path.append("..")
from psflearning.psflearninglib import psflearninglib
from psflearning import io
from psflearning.makeplots import *
import tensorflow as tf
from dotted_dict import DottedDict
gpus = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpus[0], True)

# %% [markdown]
# #### Load learned PSF model from bead data

# %%
resfile = r'E:\EMBL files\data for PSF learning\Astigmatism_beads_stacks_2um\sample\psfmodel7_zernike_vector_FD_single.h5'


f,p = io.h5.load(resfile) # load result file
L = psflearninglib()
L.param = p

# %% [markdown]
# #### display system characterizations

# %%
showzernikemap(f,p)

# %%
strehlratio = L.calstrehlratio(f)

# %%
showpsfvsdata(f,p,index=0)

# %%
fwhmx,fwhmy,fwhmz = L.calfwhm(f)
